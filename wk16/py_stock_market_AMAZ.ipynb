# %% [markdown]
# # Robbie Tovar
# ## Week 14 - 11/21 / week 16 12/3
# ### python data cleaning and visualzation project - python stock market project amazon

# %%
#The nomral imports 
import numpy as np
from numpy.random import randn, random, randint
import pandas as pd
from pandas import Series, DataFrame

#these are plotting modules and libaries we'll use
import matplotlib as mpl
import matplotlib.pyplot as plt

#command that plots appear in python 
# %matplotlib inline

# %%
#upload datset from csv file
data=pd.read_csv('AMZN.csv')

# %%
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
#data infomration and understanding 
data.head(20)
# Out:
#          Date Source        Open        High         Low       Close  \
# 0    1/3/2012  yahoo  175.889999  179.479996  175.550003  179.029999
# 1    1/4/2012  yahoo  179.210007  180.500000  176.070007  177.509995
# 2    1/5/2012  yahoo  175.940002  178.250000  174.050003  177.610001
# 3    1/6/2012  yahoo  178.070007  184.649994  177.500000  182.610001
# 4    1/9/2012  yahoo  182.759995  184.369995  177.000000  178.559998
# 5   1/10/2012  yahoo  181.100006  182.399994  177.100006  179.339996
# 6   1/11/2012  yahoo  179.639999  180.770004  178.190002  178.899994
# 7   1/12/2012  yahoo  179.419998  179.490005  175.750000  175.929993
# 8   1/13/2012  yahoo  175.809998  178.800003  173.500000  178.419998
# 9   1/17/2012  yahoo  180.149994  183.300003  178.509995  181.660004
# 10  1/18/2012  yahoo  181.940002  190.250000  181.119995  189.440002
# 11  1/19/2012  yahoo  190.880005  195.940002  190.360001  194.449997
# 12  1/20/2012  yahoo  190.710007  192.899994  189.039993  190.929993
# ...

# %%
data.tail(20)
# Out:
#             Date Source         Open         High          Low        Close  \
# 2222  10/30/2020  yahoo  3157.750000  3167.000000  3019.000000  3036.149902
# 2223   11/2/2020  yahoo  3061.739990  3079.709961  2950.120117  3004.479980
# 2224   11/3/2020  yahoo  3018.530029  3074.899902  2980.979980  3048.409912
# 2225   11/4/2020  yahoo  3159.989990  3244.850098  3139.729980  3241.159912
# 2226   11/5/2020  yahoo  3319.969971  3366.800049  3288.879883  3322.000000
# 2227   11/6/2020  yahoo  3304.639893  3322.000000  3232.000000  3311.370117
# 2228   11/9/2020  yahoo  3231.030029  3289.000000  3112.110107  3143.739990
# 2229  11/10/2020  yahoo  3095.020020  3114.000000  3019.479980  3035.020020
# 2230  11/11/2020  yahoo  3061.780029  3139.149902  3050.000000  3137.389893
# 2231  11/12/2020  yahoo  3159.949951  3175.879883  3086.050049  3110.280029
# 2232  11/13/2020  yahoo  3122.000000  3141.719971  3085.389893  3128.810059
# ...

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2241.000000  2240.000000  2242.000000  2239.000000  2241.000000
# mean    991.401419  1002.190218   979.221717   991.895355   991.190696
# std     802.269032   811.968123   790.843600   801.664757   801.654109
# min     173.809998   178.250000   172.000000   175.929993   175.929993
# 25%     320.359985   323.687500   315.807487   321.385010   320.510010
# 50%     717.380005   723.394989   712.629975   719.299988   719.070007
# 75%    1660.000000  1679.964966  1633.707459  1661.830017  1660.510010
# max    3547.000000  3552.250000  3486.689941  3531.449951  3531.449951
#
#              Volume
# count  2.242000e+03
# mean   4.118187e+06
# std    2.278888e+06
# min    0.000000e+00
# 25%    2.688550e+06
# 50%    3.528700e+06
# 75%    4.839800e+06
# max    2.385610e+07

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2242 non-null   object
#  1   Source     2242 non-null   object
#  2   Open       2241 non-null   float64
#  3   High       2240 non-null   float64
#  4   Low        2242 non-null   float64
#  5   Close      2239 non-null   float64
#  6   Adj Close  2241 non-null   float64
#  7   Volume     2242 non-null   int64
#  8   Stock      2242 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 157.8+ KB

# %%
data.shape
# Out:
# (2242, 9)

# %%
data.columns
# Out:
# Index(['Date', 'Source', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Stock'],
#       dtype='object')

# %%
data['Adj Close'].plot()

# %%
data['Adj Close'].plot(legend=True, figsize=(10,4))

# %%
#data preparation 
from pandas.api.types import is_numeric_dtype

n=0
for c in data.columns:
    if is_numeric_dtype(c):
        n+=1
        
        
print(f'numerical values: {n}, none-numerical values: {len(data.columns)-n}')
# Out:
# numerical values: 0, none-numerical values: 9

# %%
#data cleaning - preparing data for analytics, missing data
data.isnull()
# Out:
#        Date  Source   Open   High    Low  Close  Adj Close  Volume  Stock
# 0     False   False  False  False  False  False      False   False  False
# 1     False   False  False  False  False  False      False   False  False
# 2     False   False  False  False  False  False      False   False  False
# 3     False   False  False  False  False  False      False   False  False
# 4     False   False  False  False  False  False      False   False  False
# ...     ...     ...    ...    ...    ...    ...        ...     ...    ...
# 2237  False   False  False  False  False  False      False   False  False
# 2238  False   False  False  False  False  False      False   False  False
# 2239  False   False  False  False  False  False      False   False  False
# 2240  False   False  False  False  False  False      False   False  False
# 2241  False   False  False  False  False  False      False   False  False
#
# [2242 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         1
# High         2
# Low          0
# Close        3
# Adj Close    1
# Volume       0
# Stock        0
# dtype: int64

# %%
n=len(data)
n
# Out:
# 2242

# %%
data.dropna(inplace=True)

# %%
#clean abnoprmal values
data['Volume'].plot(kind='hist', bins=50)

# %%
data['Volume'].max()
# Out:
# 23856100

# %%
data['Volume'].min()
# Out:
# 0

# %%
data = data[data['Volume']>10000]

# %%
data['Volume'].sort_values().head(20)
# Out:
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# 749     1513800
# 1167    1524100
# 151     1534300
# 417     1534700
# 152     1548100
# 1160    1563300
# 416     1566400
# Name: Volume, dtype: int64

# %%
#remove all coluimns that have constant or single 
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
constant_columns=[]
for c in data.columns:
    n = len(data[c].unique())
    if n == 1:
        constant_columns.append(c)
        
        
print('contant columns: ', constant_columns)
# Out:
# contant columns:  ['Source', 'Stock']

# %%
data.drop(columns=constant_columns, axis=1, inplace = True)
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume
# 0      179.029999  5110800
# 1      177.509995  4205200
# 2      177.610001  3809100
# ...

# %%
#adding year, month, day columns to the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 139.2+ KB

# %%
dateObject = pd.DatetimeIndex(data['Date'])

# %%
data['Day'] = dateObject.day
data['Month']=dateObject.month
data['Year']= dateObject.year
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data[['Date', 'Year', 'Month','Day']]
# Out:
#             Date  Year  Month  Day
# 0       1/3/2012  2012      1    3
# 1       1/4/2012  2012      1    4
# 2       1/5/2012  2012      1    5
# 3       1/6/2012  2012      1    6
# 4       1/9/2012  2012      1    9
# ...          ...   ...    ...  ...
# 2237  11/20/2020  2020     11   20
# 2238  11/23/2020  2020     11   23
# 2239  11/24/2020  2020     11   24
# 2240  11/25/2020  2020     11   25
# 2241  11/27/2020  2020     11   27
#
# [2228 rows x 4 columns]

# %%
#use visualtization for data analysis
result = data[['Year', 'Volume']].groupby('Year').sum()
result
# Out:
#           Volume
# Year
# 2012   975492400
# 2013   747905700
# 2014  1029066700
# 2015   957102000
# 2016  1038756300
# 2017   882705400
# 2018  1417897600
# 2019   974729400
# 2020  1166035700

# %%
result = data[['Month', 'Volume']].groupby('Month').sum()
result
# Out:
#           Volume
# Month
# 1      884620500
# 2      846030200
# 3      839584500
# 4      890804000
# 5      693382700
# 6      671267700
# 7      792035200
# 8      633655400
# 9      650017700
# 10     897270200
# 11     743073600
# 12     647949500

# %%
result.plot(figsize=(8,6), y='Volume', fontsize=12,title="Stocks Volumne Over Months")
plt.ylabel("Stocks Volume")
# Out:
# Text(0, 0.5, 'Stocks Volume')

# %%
result = data[['Year', 'Volume']].groupby('Year').sum()
result
# Out:
#           Volume
# Year
# 2012   975492400
# 2013   747905700
# 2014  1029066700
# 2015   957102000
# 2016  1038756300
# 2017   882705400
# 2018  1417897600
# 2019   974729400
# 2020  1166035700

# %%
result.plot(figsize=(8,6), y='Volume', fontsize=12,title="Stocks Volumne Over years")
plt.ylabel("Stocks volume")
# Out:
# Text(0, 0.5, 'Stocks volume')

# %%
result = data[['Day', 'Volume']].groupby('Day').mean()
result
# Out:
#            Volume
# Day
# 1    4.499956e+06
# 2    4.236592e+06
# 3    4.141493e+06
# 4    4.172901e+06
# 5    3.962899e+06
# 6    3.891352e+06
# 7    3.891741e+06
# 8    3.685434e+06
# 9    3.985105e+06
# 10   3.812632e+06
# 11   3.746887e+06
# 12   3.775222e+06
# 13   3.849997e+06
# 14   3.836888e+06
# 15   4.211287e+06
# 16   4.004870e+06
# 17   3.902925e+06
# 18   4.003701e+06
# 19   3.888446e+06
# 20   3.960612e+06
# 21   3.989060e+06
# 22   3.482028e+06
# 23   3.836312e+06
# 24   4.581157e+06
# 25   4.536282e+06
# 26   4.714437e+06
# 27   4.870136e+06
# 28   4.563546e+06
# 29   4.596324e+06
# 30   4.789814e+06
# 31   5.031240e+06

# %%
result = data[['Day', 'Volume']].groupby('Day').count()
result
# Out:
#      Volume
# Day
# 1        66
# 2        72
# 3        70
# 4        69
# 5        75
# 6        77
# 7        73
# 8        74
# 9        75
# 10       76
# 11       76
# 12       76
# 13       79
# 14       73
# 15       71
# 16       71
# 17       75
# 18       73
# 19       74
# 20       75
# 21       72
# 22       71
# 23       75
# 24       75
# 25       67
# 26       73
# 27       76
# 28       71
# 29       67
# 30       66
# 31       45

# %%
result = data[['Day', 'Adj Close']].groupby('Day').sum()
result
# Out:
#         Adj Close
# Day
# 1    65415.159908
# 2    70951.899748
# 3    68975.719329
# 4    67382.220366
# 5    73128.720229
# 6    78207.070115
# 7    70641.720229
# 8    72232.220537
# 9    74521.869971
# 10   74220.249723
# 11   74417.759990
# 12   75827.109803
# 13   79224.770416
# 14   73791.020248
# 15   70681.279567
# 16   73232.980014
# 17   74177.609788
# 18   72558.399686
# 19   72725.190337
# 20   76395.450013
# 21   72810.020079
# 22   71218.510162
# 23   74091.889937
# 24   75882.449762
# 25   66075.279874
# 26   71888.460188
# 27   77568.279954
# 28   71177.740287
# 29   67596.539874
# 30   66766.450091
# 31   44875.819715

# %%
#show the closing per data
data[['Date', 'Adj Close']].plot(figsize=(10,8), x='Date', y='Adj Close', fontsize=12,title="Closing price over the past 8 years")

# %%
data.info()

# %%
date['Date']=pd.to_datetime(data['Date'], format='%m/%d/%y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-5c334efa359b> in <module>
# ----> 1 date['Date']=pd.to_datetime(data['Date'],format='%m/%d/%y')
#
# ...

# %%
data[['Date', 'Adj Close']].plot(figsize=(10,8), x='Date', y='Adj Close', fontsize=12,title="Closing price over the past 8 years")

# %%
#using filters
#plot the adj close prices that are smaller than the open prices
# and after 2015
#first query data for year > 2015
data[data['Year']>2015]
# Out:
#             Date         Open         High          Low        Close  \
# 1006    1/4/2016   656.289978   657.719971   627.510010   636.989990
# 1007    1/5/2016   646.859985   646.909973   627.650024   633.789978
# 1008    1/6/2016   622.000000   639.789978   620.309998   632.650024
# 1009    1/7/2016   621.799988   630.000000   605.210022   607.940002
# 1010    1/8/2016   619.659973   624.140015   606.000000   607.049988
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume  Day  Month  Year
# 1006   636.989990  9314500    4      1  2016
# 1007   633.789978  5822600    5      1  2016
# ...

# %%
#uery data for adj close open price
data[data['Adj Close']<data['Open']]
# Out:
#             Date         Open         High          Low        Close  \
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# 5      1/10/2012   181.100006   182.399994   177.100006   179.339996
# 6      1/11/2012   179.639999   180.770004   178.190002   178.899994
# 7      1/12/2012   179.419998   179.490005   175.750000   175.929993
# ...          ...          ...          ...          ...          ...
# 2234  11/17/2020  3183.540039  3189.250000  3135.260010  3135.659912
# 2235  11/18/2020  3134.000000  3140.000000  3105.100098  3105.459961
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume  Day  Month  Year
# 1      177.509995  4205200    4      1  2012
# 4      178.559998  5056900    9      1  2012
# ...

# %%
filter1 = data['Year']>2015
filter1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2237     True
# 2238     True
# 2239     True
# 2240     True
# 2241     True
# Name: Year, Length: 2228, dtype: bool

# %%
filter2 = data['Adj Close'] < data['Open']
filter2
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2237     True
# 2238     True
# 2239    False
# 2240    False
# 2241     True
# Length: 2228, dtype: bool

# %%
result = data[filter1 & filter2]
result
# Out:
#             Date         Open         High          Low        Close  \
# 1006    1/4/2016   656.289978   657.719971   627.510010   636.989990
# 1007    1/5/2016   646.859985   646.909973   627.650024   633.789978
# 1009    1/7/2016   621.799988   630.000000   605.210022   607.940002
# 1010    1/8/2016   619.659973   624.140015   606.000000   607.049988
# 1012   1/12/2016   625.250000   625.989990   612.239990   617.890015
# ...          ...          ...          ...          ...          ...
# 2234  11/17/2020  3183.540039  3189.250000  3135.260010  3135.659912
# 2235  11/18/2020  3134.000000  3140.000000  3105.100098  3105.459961
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume  Day  Month  Year
# 1006   636.989990  9314500    4      1  2016
# 1007   633.789978  5822600    5      1  2016
# ...

# %%
result[['Year','Adj Close', 'Open']]
# Out:
#       Year    Adj Close         Open
# 1006  2016   636.989990   656.289978
# 1007  2016   633.789978   646.859985
# 1009  2016   607.940002   621.799988
# 1010  2016   607.049988   619.659973
# 1012  2016   617.890015   625.250000
# ...    ...          ...          ...
# 2234  2020  3135.659912  3183.540039
# 2235  2020  3105.459961  3134.000000
# 2237  2020  3099.399902  3117.020020
# 2238  2020  3098.389893  3116.699951
# 2241  2020  3195.340088  3211.260010
#
# [616 rows x 3 columns]

# %%
len(result)
# Out:
# 616

# %%
r = result[['Year', 'Adj Close']].groupby('Year').count()
r
# Out:
#       Adj Close
# Year
# 2016        127
# 2017        128
# 2018        124
# 2019        125
# 2020        112

# %%
r.idxmax()
# Out:
# Adj Close    2017
# dtype: int64

# %%
r.plot.bar(figsize=(10,8),y='Adj Close', fontsize=12, legend=True, title="Adj Close from 2016 to 2019")
plt.ylabel('Number of stocks')
# Out:
# Text(0, 0.5, 'Number of stocks')

# %%
#query the data to answer some questions
#find the months that have the hgihest and lowest number of volume 
r = data[['Month', 'Volume']].groupby('Month').sum()
r
# Out:
#           Volume
# Month
# 1      884620500
# 2      846030200
# 3      839584500
# 4      890804000
# 5      693382700
# 6      671267700
# 7      792035200
# 8      633655400
# 9      650017700
# 10     897270200
# 11     743073600
# 12     647949500

# %%
r.min()
# Out:
# Volume    633655400
# dtype: int64

# %%
r.max()
# Out:
# Volume    897270200
# dtype: int64

# %%
r.idxmax()
# Out:
# Volume    10
# dtype: int64

# %%
r.idxmin()
# Out:
# Volume    8
# dtype: int64

# %%
print('The month with the lowest volume',r.idxmin()[0], 'Volume', r.min()[0])
# Out:
# The month with the lowest volume 8 Volume 633655400

# %%
print('The month with the highest volume', r.idxmax()[0], 'Volume', r.max()[0])
# Out:
# The month with the highest volume 10 Volume 897270200

# %%
#find teh month and day that has the lowest (adj close) closingaverage price 
r = data[['Month', 'Day', 'Adj Close']].groupby(['Month','Day']).mean()
r
# Out:
#             Adj Close
# Month Day
# 1     2    931.658335
#       3    881.009992
#       4    769.301659
#       5    624.636002
#       6    700.508339
# ...               ...
# 12    27   988.581681
#       28   871.326001
#       29   735.157494
#       30   797.900000
#       31   830.951660
#
# [363 rows x 1 columns]

# %%
r.min()[0]
# Out:
# 366.105011

# %%
r.idxmax()[0]
# Out:
# (9, 1)

# %%
r.idxmin()[0]
# Out:
# (2, 29)

# %%
r = data[['Date', 'Adj Close']].groupby('Date')
r

# %%
r.min()
# Out:
#              Adj Close
# Date
# 1/10/2012   179.339996
# 1/10/2013   265.339996
# 1/10/2014   397.660004
# 1/10/2017   795.900024
# 1/10/2018  1254.329956
# ...                ...
# 9/9/2014    329.750000
# 9/9/2015    516.890015
# 9/9/2016    760.140015
# 9/9/2019   1831.349976
# 9/9/2020   3268.610107
#
# [2228 rows x 1 columns]

# %%
r.idxmin()
# Out:
#            Adj Close
# Date
# 1/10/2012          5
# 1/10/2013        256
# 1/10/2014        508
# 1/10/2017       1263
# 1/10/2018       1515
# ...              ...
# 9/9/2014         674
# 9/9/2015         926
# 9/9/2016        1179
# 9/9/2019        1932
# 9/9/2020        2185
#
# [2228 rows x 1 columns]
